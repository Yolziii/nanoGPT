# %%
uk_chats = '''оаи
етнлсврі,удкм.пяьбзгйчюх-жшє!НТІїПцАСВ"ЗщМДО?У—КЯБы;ЧЩ:ГРЛХ'ИЙЦфШ1()ЖI84ЕЄ25ЇФV3790э6*ЮґeXъNЭҐTdumЬCDUBA'''

# %%
[(ord(x)) for x in uk_chats]

# %%
list(uk_chats.encode('utf-16'))
